# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
plt.style.use('ggplot')
pd.options.display.max_columns=200
#pd.options.display.max_rows=40

# %%
df=pd.read_csv('coaster_db.csv')

# %%
df
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status   Type            Manufacturer  Year_Introduced  Latitude  \
# 0  Removed   Wood  LaMarcus Adna Thompson             1884   40.5740
# 1  Removed   Wood            Lina Beecher             1895   40.5780
# 2   Closed  Other                     NaN             1896   41.5800
# 3  Removed  Steel          Edwin Prescott             1901   40.5745
# 4  Removed  Steel          Edwin Prescott             1901   39.3538
#
#    longitude Type_Main Opening_Date_Clean  Speed_Mph  Height_ft  \
# ...

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Type', 'Manufacturer',
#        'Year_Introduced', 'Latitude', 'longitude', 'Type_Main',
#        'Opening_Date_Clean', 'Speed_Mph', 'Height_ft', 'Inversions_Clean',
#        'Gforce_Clean'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Coaster_Name                  object
# Location                      object
# Status                        object
# Type                          object
# Manufacturer                  object
# Year_Introduced                int64
# Latitude                     float64
# longitude                    float64
# Type_Main                     object
# Opening_Date_Clean    datetime64[ns]
# Speed_Mph                    float64
# Height_ft                    float64
# Inversions_Clean               int64
# Gforce_Clean                 float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Type', 'Manufacturer',
#        'Year_Introduced', 'Latitude', 'longitude', 'Type_Main',
#        'Opening_Date_Clean', 'Speed_Mph', 'Height_ft', 'Inversions_Clean',
#        'Gforce_Clean'],
#       dtype='object')

# %%
df=df[['coaster_name', 
        #'Length', 'Speed', 
        'Location', 'Status', 
        #'Opening date',
       'Type', 
       'Manufacturer', 
       #'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', 
        #'Opened', 
        #'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean',
       #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
       #'height_value', 'height_unit',
       'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 df=df[['coaster_name',
#       2         #'Length', 'Speed',
#       3         'Location', 'Status',
#       4         #'Opening date',
#       5        'Type',
#       6        'Manufacturer',
#       7        #'Height restriction', 'Model', 'Height',
#       8        #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#       9        #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#      10        #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#      11        #'Track layout', 'Fastrack available', 'Soft opening date.1',
#      12        #'Closing date',
#      13         #'Opened',
#      14         #'Replaced by', 'Website',
#      15        #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
# ...

# %%
df
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
#Another way of subsetting the data set
#df.drop(['Opening date'],axis=1)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Type                   object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df['opening_date_clean']=pd.to_datetime(df['opening_date_clean'])

# %%
#rename our columns

df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Type', 'Manufacturer',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed_mph', 'height_ft', 'Inversions_clean',
#        'Gforce_clean'],
#       dtype='object')

# %%
df.rename(columns={'coaster_name':'Coaster_Name','year_introduced':'Year_Introduced',
                   'latitude':'Latitude','opening_date_clean':'Opening_Date_Clean',
                   'speed_mph':'Speed_Mph','height_ft':'Height_ft','Inversions_clean':'Inversions_Clean','Gforce_clean':'Gforce_Clean'},inplace=True)

# %%
df.isna().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Type                    0
# Manufacturer           59
# Year_Introduced         0
# Latitude              275
# longitude             275
# Type_Main               0
# Opening_Date_Clean    250
# Speed_Mph             150
# Height_ft             916
# Inversions_Clean        0
# Gforce_Clean          725
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Type, Manufacturer, Year_Introduced, Latitude, longitude, Type_Main, Opening_Date_Clean, Speed_Mph, Height_ft, Inversions_Clean, Gforce_Clean]
# Index: []

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                          Type  \
# 43               Removed                          Wood
# ...

# %%
#checking an example duplicate

df.query('Coaster_Name=="Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status  Type  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Wood
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Wood
#
#           Manufacturer  Year_Introduced  Latitude  longitude Type_Main  \
# 39  Traver Engineering             1926   42.8617   -79.0598      Wood
# 43  Traver Engineering             1927   42.8617   -79.0598      Wood
#
#    Opening_Date_Clean  Speed_Mph  Height_ft  Inversions_Clean  Gforce_Clean
# 39         1926-01-01       60.0        NaN                 0           4.0
# 43         1926-01-01       60.0        NaN                 0           4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Type', 'Manufacturer',
#        'Year_Introduced', 'Latitude', 'longitude', 'Type_Main',
#        'Opening_Date_Clean', 'Speed_Mph', 'Height_ft', 'Inversions_Clean',
#        'Gforce_Clean'],
#       dtype='object')

# %%
#removes all duplicate values in the below three columns
df=df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date_Clean'])].reset_index(drop=True).copy()

# %%
df
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.shape
# Out:
# (990, 14)

# %% [markdown]
# done cleaning the data

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
ax=df['Year_Introduced'].value_counts()\
    .head(10)\
    .plot(kind='bar',title='Top 10 Years Coasters Introduced')

ax.set_xlabel('Year Introduced')
ax.set_ylabel('Sum')
# Out:
# Text(0, 0.5, 'Sum')

# %%
ax=df['Speed_Mph'].plot(kind='hist',bins=20,title='Coaster Speed Mph')

ax.set_xlabel('Speed Mph')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax=df['Speed_Mph'].plot(kind='kde',title='Coaster Speed Mph')

ax.set_xlabel('Speed Mph')
ax.set_ylabel('Frequency')

#kde plots are less crowded so easier to understand this kind of data
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Feature Relationships
# * Scatter Plot
# * Heatmap Correlation
# * Pairplot
# * Groupby comparisons

# %%
df
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.plot(kind='scatter',x='Speed_Mph',y='Height_ft',title='Coaster Speed vs Height')

plt.show()

# %%
sns.scatterplot(x='Speed_Mph',y='Height_ft',data=df,hue='Year_Introduced')
# Out:
# <Axes: xlabel='Speed_Mph', ylabel='Height_ft'>

# %%
#pairplot helps you compare muliple features in dataset

sns.pairplot(df,vars=['Year_Introduced','Speed_Mph','Height_ft','Inversions_Clean','Gforce_Clean'],
             hue='Type_Main'
             
             )
plt.show()

# %%
df_corr=df[['Year_Introduced','Speed_Mph','Height_ft','Inversions_Clean','Gforce_Clean']].dropna().corr()

# %%
sns.heatmap(df_corr,annot=True)

#annot=true helps to make us see raw values in the heatmap
# Out:
# <Axes: >

# %% [markdown]
# Question
# - What are the locations with the fastest roller coasters (minimum of  10 )

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status   Type            Manufacturer  Year_Introduced  Latitude  \
# 0  Removed   Wood  LaMarcus Adna Thompson             1884   40.5740
# 1  Removed   Wood            Lina Beecher             1895   40.5780
# 2   Closed  Other                     NaN             1896   41.5800
# 3  Removed  Steel          Edwin Prescott             1901   40.5745
# 4  Removed  Steel          Edwin Prescott             1901   39.3538
#
#    longitude Type_Main Opening_Date_Clean  Speed_Mph  Height_ft  \
# ...

# %%
df['Location'].value_counts()
# Out:
# Location
# Other                            181
# Kings Island                      19
# Cedar Point                       18
# Six Flags Magic Mountain          17
# Hersheypark                       16
#                                 ...
# Granada Studios Tour               1
# Funtown Splashtown USA             1
# Tolchester Beach Park              1
# Suzuka, Mie Prefecture, Japan      1
# Epcot                              1
# Name: count, Length: 280, dtype: int64

# %%
ax=df.query('Location!="Other"').groupby('Location')['Speed_Mph'].agg(['mean','count']).query('count>=10').sort_values('mean')['mean']\
    .plot(kind='barh',title='Average Coast speed by location')
    
ax.set_xlabel('Average Coaster Speed')    
plt.show()
